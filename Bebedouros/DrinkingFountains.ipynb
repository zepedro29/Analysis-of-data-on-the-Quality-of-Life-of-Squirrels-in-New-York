# %%
pip install delta-spark
# Out:
# Requirement already satisfied: delta-spark in /opt/conda/lib/python3.10/site-packages (2.1.1)
# Requirement already satisfied: pyspark<3.4.0,>=3.3.0 in /usr/local/spark-3.3.0-bin-hadoop3/python (from delta-spark) (3.3.0)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from delta-spark) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=1.0.0->delta-spark) (3.8.1)
# Requirement already satisfied: py4j==0.10.9.5 in /opt/conda/lib/python3.10/site-packages (from pyspark<3.4.0,>=3.3.0->delta-spark) (0.10.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from os import PathLike
from hdfs import InsecureClient
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *
from pyspark.sql.functions import *
from pyspark.sql.types import LongType, StringType, StructField, StructType, BooleanType, ArrayType, IntegerType,FloatType

warehouse_location = 'hdfs://hdfs-nn:9870/trabalho'

builder = SparkSession \
    .builder \
    .master("local[2]") \
    .appName("Python Spark DataFrames and SQL") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
hdfs_path = "hdfs://hdfs-nn:9000/trabalho/bronze/DrinkingFountains.csv"

customSchema = StructType([
    StructField("FountainTy", StringType(), True),        
    StructField("the_geom", StringType(), True),
    StructField("OBJECTID", IntegerType(), True),
    StructField("Position", StringType(), True),
    StructField("Collection", StringType(), True),
    StructField("Painted", StringType(), True),
    StructField("GISPROPNUM", StringType(), True), 
    StructField("SIGNNAME", StringType(), True), 
    StructField("BOROUGH", StringType(), True), 
    StructField("FountainCo", IntegerType(), True), 
    StructField("GISOBJID", IntegerType(), True),
    StructField("SYSTEM", StringType(), True),
    StructField("DEPARTMENT", StringType(), True),
    StructField("PARENTID", StringType(), True),
    StructField("DESCRIPTIO", StringType(), True),
    StructField("FEATURESTA", StringType(), True),
    

])

projeto_green = spark \
            .read\
            .option("delimiter",";")\
            .option("header","true")\
            .schema(customSchema) \
            .csv(hdfs_path)
projeto_green.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square       B           2  100038957.0
# 1                Robert Moses Playground       M           1  100039303.0
# 2                           Chelsea Park       M           1  100039632.0
# 3        John V. Lindsay East River Park       M           1  100039936.0
# 4                        Charlie's Place       B           1  100040304.0
# ...                                  ...     ...         ...          ...
# 3115                       Canarsie Park       B           1  100039874.0
# 3116                      Crocheron Park       Q           1  100040158.0
# 3117                       Virginia Park       X           1  100040464.0
# 3118     John V. Lindsay East River Park       M           1  100039941.0
# 3119                Holcombe Rucker Park       M           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green1 = projeto_green.withColumn(
    "BOROUGH",
    when(projeto_green.BOROUGH.endswith('B'),regexp_replace(projeto_green.BOROUGH,'B','Brooklyn')) \
    .when(projeto_green.BOROUGH.endswith('M'),regexp_replace(projeto_green.BOROUGH,'M','Manhattan')) \
    .when(projeto_green.BOROUGH.endswith('Q'),regexp_replace(projeto_green.BOROUGH,'Q','Queens')) \
    .when(projeto_green.BOROUGH.endswith('R'),regexp_replace(projeto_green.BOROUGH,'R','Staten Island')) \
    .when(projeto_green.BOROUGH.endswith('X'),regexp_replace(projeto_green.BOROUGH,'X','Bronx')) \
)

projeto_green1.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "Position",
    when(
        (col("Position").isNull() | (col("Position") == None)), 
        "Desconhecida"
    ).otherwise(col("Position")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                       Desconhecida
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "Painted",
    when(
        (col("Painted").isNull() | (col("Painted") == None)), 
        "Desconhecido"
    ).otherwise(col("Painted")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection       Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000            no       B100
# 1     02/22/2018 12:00:00 AM +0000            no       M158
# 2     02/27/2018 12:00:00 AM +0000           yes       M011
# 3     04/04/2018 12:00:00 AM +0000            no       M144
# 4     05/29/2018 12:00:00 AM +0000  Desconhecido       B302
# ...                            ...           ...        ...
# 3115  03/05/2018 12:00:00 AM +0000            no       B018
# 3116  05/01/2018 12:00:00 AM +0000            no       Q012
# 3117  11/30/1899 12:00:00 AM +0000  Desconhecido     X148L1
# 3118  04/04/2018 12:00:00 AM +0000           yes       M144
# 3119  05/09/2018 12:00:00 AM +0000           yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "GISPROPNUM",
    when(
        (col("GISPROPNUM").isNull() | (col("GISPROPNUM") == None)), 
        "Desconhecido"
    ).otherwise(col("GISPROPNUM")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "SIGNNAME",
    when(
        (col("SIGNNAME").isNull() | (col("SIGNNAME") == None)), 
        "Desconhecido"
    ).otherwise(col("SIGNNAME")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "GISOBJID",
    when(
        (col("GISOBJID").isNull() | (col("GISOBJID") == None)), 
        "Desconhecido"
    ).otherwise(col("GISOBJID")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo   GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957
# 1                Robert Moses Playground  Manhattan           1  100039303
# 2                           Chelsea Park  Manhattan           1  100039632
# 3        John V. Lindsay East River Park  Manhattan           1  100039936
# 4                        Charlie's Place   Brooklyn           1  100040304
# ...                                  ...        ...         ...        ...
# 3115                       Canarsie Park   Brooklyn           1  100039874
# 3116                      Crocheron Park     Queens           1  100040158
# 3117                       Virginia Park      Bronx           1  100040464
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941
# 3119                Holcombe Rucker Park  Manhattan           2  100040181
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green2 = projeto_green1.withColumn(
    "PARENTID",
    when(
        (col("PARENTID").isNull() | (col("PARENTID") == None)), 
        "Desconhecido"
    ).otherwise(col("PARENTID")))
projeto_green2.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position  \
# 0         1589                                        Out in Open
# 1         1921                                      In Playground
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...
# 3         2585            Just Outside Playground, Near Ballfield
# 4         2917                            In Shade, In Playground
# ...        ...                                                ...
# 3115      2418                        Out in Open, Near Ballfield
# 3116      2750                            Just Outside Playground
# 3117      3082                                               None
# 3118      2564                                     Near Ballfield
# 3119      2773          Under Tree, In Playground, Near Ballfield
#
#                         Collection Painted GISPROPNUM  \
# 0     02/10/2018 12:00:00 AM +0000      no       B100
# 1     02/22/2018 12:00:00 AM +0000      no       M158
# 2     02/27/2018 12:00:00 AM +0000     yes       M011
# 3     04/04/2018 12:00:00 AM +0000      no       M144
# 4     05/29/2018 12:00:00 AM +0000    None       B302
# ...                            ...     ...        ...
# 3115  03/05/2018 12:00:00 AM +0000      no       B018
# 3116  05/01/2018 12:00:00 AM +0000      no       Q012
# 3117  11/30/1899 12:00:00 AM +0000    None     X148L1
# 3118  04/04/2018 12:00:00 AM +0000     yes       M144
# 3119  05/09/2018 12:00:00 AM +0000     yes       M216
#
#                                 SIGNNAME    BOROUGH  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square   Brooklyn           2  100038957.0
# 1                Robert Moses Playground  Manhattan           1  100039303.0
# 2                           Chelsea Park  Manhattan           1  100039632.0
# 3        John V. Lindsay East River Park  Manhattan           1  100039936.0
# 4                        Charlie's Place   Brooklyn           1  100040304.0
# ...                                  ...        ...         ...          ...
# 3115                       Canarsie Park   Brooklyn           1  100039874.0
# 3116                      Crocheron Park     Queens           1  100040158.0
# 3117                       Virginia Park      Bronx           1  100040464.0
# 3118     John V. Lindsay East River Park  Manhattan           1  100039941.0
# 3119                Holcombe Rucker Park  Manhattan           2  100040181.0
#
#              SYSTEM DEPARTMENT PARENTID  \
# 0       B100-DF0647       B-11     B100
# 1       M158-DF0068       M-06     M158
# 2       M011-DF0209       M-04     M011
# 3       M144-DF0392       M-03     M144
# 4       B302-DF0897       B-03     B302
# ...             ...        ...      ...
# 3115    B018-DF0817       B-18     B018
# 3116    Q012-DF0750       Q-11     Q012
# 3117  X148L1-DF0470       X-09   X148L1
# 3118    M144-DF0371       M-03     M144
# 3119    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
# [3120 rows x 16 columns]

# %%
projeto_green3 = projeto_green2.withColumn('Data_Collection', split(projeto_green2['Collection'], ' ').getItem(0)) \
                                                .drop(col("Collection"))
projeto_green3.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position Painted  \
# 0         1589                                        Out in Open      no
# 1         1921                                      In Playground      no
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...     yes
# 3         2585            Just Outside Playground, Near Ballfield      no
# 4         2917                            In Shade, In Playground    None
# ...        ...                                                ...     ...
# 3115      2418                        Out in Open, Near Ballfield      no
# 3116      2750                            Just Outside Playground      no
# 3117      3082                                               None    None
# 3118      2564                                     Near Ballfield     yes
# 3119      2773          Under Tree, In Playground, Near Ballfield     yes
#
#      GISPROPNUM                            SIGNNAME    BOROUGH  FountainCo  \
# 0          B100  Seth Low Playground/ Bealin Square   Brooklyn           2
# 1          M158             Robert Moses Playground  Manhattan           1
# 2          M011                        Chelsea Park  Manhattan           1
# 3          M144     John V. Lindsay East River Park  Manhattan           1
# 4          B302                     Charlie's Place   Brooklyn           1
# ...         ...                                 ...        ...         ...
# 3115       B018                       Canarsie Park   Brooklyn           1
# 3116       Q012                      Crocheron Park     Queens           1
# 3117     X148L1                       Virginia Park      Bronx           1
# 3118       M144     John V. Lindsay East River Park  Manhattan           1
# 3119       M216                Holcombe Rucker Park  Manhattan           2
#
#          GISOBJID         SYSTEM DEPARTMENT PARENTID  \
# 0     100038957.0    B100-DF0647       B-11     B100
# 1     100039303.0    M158-DF0068       M-06     M158
# 2     100039632.0    M011-DF0209       M-04     M011
# 3     100039936.0    M144-DF0392       M-03     M144
# 4     100040304.0    B302-DF0897       B-03     B302
# ...           ...            ...        ...      ...
# 3115  100039874.0    B018-DF0817       B-18     B018
# 3116  100040158.0    Q012-DF0750       Q-11     Q012
# 3117  100040464.0  X148L1-DF0470       X-09   X148L1
# 3118  100039941.0    M144-DF0371       M-03     M144
# 3119  100040181.0    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA  \
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
#      Data_Collection
# 0         02/10/2018
# 1         02/22/2018
# 2         02/27/2018
# 3         04/04/2018
# 4         05/29/2018
# ...              ...
# 3115      03/05/2018
# 3116      05/01/2018
# 3117      11/30/1899
# 3118      04/04/2018
# 3119      05/09/2018
#
# [3120 rows x 16 columns]

# %%
projeto_green4 = projeto_green3.withColumn("Data_Collection", to_date(col("Data_Collection"), "MM/dd/yyyy")) \


projeto_green4 = projeto_green4.withColumn('Mes', (split(projeto_green4['Data_Collection'], '-').getItem(1)).cast(IntegerType()))
projeto_green4.toPandas()
# Out:
#                   FountainTy                                      the_geom  \
# 0                 F High Low  POINT (-73.98659181365889 40.60753207315604)
# 1                          C   POINT (-73.96862765692859 40.7480871896291)
# 2                          D  POINT (-74.0003631604654 40.750036026114756)
# 3                          D  POINT (-73.97290101781864 40.72386196549101)
# 4                          C  POINT (-73.94639259466328 40.69933443616386)
# ...                      ...                                           ...
# 3115                       D  POINT (-73.90020355545877 40.62611516481206)
# 3116                       C   POINT (-73.7688486244796 40.77023172437061)
# 3117                       A  POINT (-73.86256527267528 40.83342686523247)
# 3118            E Wheelchair   POINT (-73.97375555702659 40.7182972633732)
# 3119  Bottle Filler High Low  POINT (-73.93625399249159 40.82937454395533)
#
#       OBJECTID                                           Position Painted  \
# 0         1589                                        Out in Open      no
# 1         1921                                      In Playground      no
# 2         2253  Under Tree, Near Ballfield, Just Outside Playg...     yes
# 3         2585            Just Outside Playground, Near Ballfield      no
# 4         2917                            In Shade, In Playground    None
# ...        ...                                                ...     ...
# 3115      2418                        Out in Open, Near Ballfield      no
# 3116      2750                            Just Outside Playground      no
# 3117      3082                                               None    None
# 3118      2564                                     Near Ballfield     yes
# 3119      2773          Under Tree, In Playground, Near Ballfield     yes
#
#      GISPROPNUM                            SIGNNAME    BOROUGH  FountainCo  \
# 0          B100  Seth Low Playground/ Bealin Square   Brooklyn           2
# 1          M158             Robert Moses Playground  Manhattan           1
# 2          M011                        Chelsea Park  Manhattan           1
# 3          M144     John V. Lindsay East River Park  Manhattan           1
# 4          B302                     Charlie's Place   Brooklyn           1
# ...         ...                                 ...        ...         ...
# 3115       B018                       Canarsie Park   Brooklyn           1
# 3116       Q012                      Crocheron Park     Queens           1
# 3117     X148L1                       Virginia Park      Bronx           1
# 3118       M144     John V. Lindsay East River Park  Manhattan           1
# 3119       M216                Holcombe Rucker Park  Manhattan           2
#
#          GISOBJID         SYSTEM DEPARTMENT PARENTID  \
# 0     100038957.0    B100-DF0647       B-11     B100
# 1     100039303.0    M158-DF0068       M-06     M158
# 2     100039632.0    M011-DF0209       M-04     M011
# 3     100039936.0    M144-DF0392       M-03     M144
# 4     100040304.0    B302-DF0897       B-03     B302
# ...           ...            ...        ...      ...
# 3115  100039874.0    B018-DF0817       B-18     B018
# 3116  100040158.0    Q012-DF0750       Q-11     Q012
# 3117  100040464.0  X148L1-DF0470       X-09   X148L1
# 3118  100039941.0    M144-DF0371       M-03     M144
# 3119  100040181.0    M216-DF0524       M-10     M216
#
#                                              DESCRIPTIO FEATURESTA  \
# 0                               F High Low, Out in Open     Active
# 1                                      C, In Playground     Active
# 2     D, Under Tree, Near Ballfield, Just Outside Pl...     Active
# 3            D, Just Outside Playground, Near Ballfield     Active
# 4                            C, In Shade, In Playground     Active
# ...                                                 ...        ...
# 3115                     D, Out in Open, Near Ballfield     Active
# 3116                         C, Just Outside Playground     Active
# 3117                                                  A     Active
# 3118                       E Wheelchair, Near Ballfield     Active
# 3119  Bottle Filler High Low, Under Tree, In Playgro...     Active
#
#      Data_Collection  Mes
# 0         2018-02-10    2
# 1         2018-02-22    2
# 2         2018-02-27    2
# 3         2018-04-04    4
# 4         2018-05-29    5
# ...              ...  ...
# 3115      2018-03-05    3
# 3116      2018-05-01    5
# 3117      1899-11-30   11
# 3118      2018-04-04    4
# 3119      2018-05-09    5
#
# [3120 rows x 17 columns]

# %%
spark.sql(
    """
    DROP TABLE IF EXISTS Projeto.DrinkingFountains
    """
)

spark.sql(
    """
    DROP DATABASE IF EXISTS Projeto CASCADE
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    create database Projeto location 'hdfs://hdfs-nn:9000/trabalho/silver/Projeto.db'
    """
)
# Out:
# DataFrame[]

# %%
spark.sql(
    """
    CREATE EXTERNAL TABLE Projeto.DrinkingFountains (
        FountainTy VARCHAR(50),
        the_geom VARCHAR(50),
        OBJECTID INT,
        Position VARCHAR(250),
        Painted VARCHAR(50),
        GISPROPNUM VARCHAR(250),
        SIGNNAME VARCHAR(250),
        FountainCo INT,
        GISOBJID INT,
        SYSTEM VARCHAR(250),
        DEPARTMENT VARCHAR(250),
        PARENTID VARCHAR(250),
        DESCRIPTIO VARCHAR(250),
        FEATURESTA VARCHAR(250),
        Data_Collection date,
        Mes INT
    )
    USING DELTA
    PARTITIONED BY (
        BOROUGH VARCHAR(250)
        
    )
    LOCATION 'hdfs://hdfs-nn:9000/trabalho/silver/Projeto.db/DrinkingFountains'
    """
)
# Out:
# DataFrame[]

# %%
projeto_green4 \
    .select("FountainTy","the_geom","OBJECTID","Position","Painted",
            "GISPROPNUM","SIGNNAME", "BOROUGH", "FountainCo","GISOBJID","SYSTEM","DEPARTMENT",
            "PARENTID", "DESCRIPTIO", "FEATURESTA", "Data_Collection", "Mes") \
    .write \
    .mode("overwrite") \
    .partitionBy("BOROUGH") \
    .format("delta") \
    .save("hdfs://hdfs-nn:9000/trabalho/silver/Projeto.db/DrinkingFountains")

# %%
spark.table("Projeto.DrinkingFountains").toPandas()
# Out:
#         FountainTy                                       the_geom  OBJECTID  \
# 0       F High Low   POINT (-73.98659181365889 40.60753207315604)      1589
# 1                C   POINT (-73.94639259466328 40.69933443616386)      2917
# 2     E Wheelchair  POINT (-73.92412001948213 40.703148631662614)        23
# 3                C  POINT (-74.01152114448477 40.630582530228764)      1898
# 4                C  POINT (-73.98647089425904 40.660201255822955)      2894
# ...            ...                                            ...       ...
# 3115  E Wheelchair    POINT (-74.0792508385633 40.62266148329357)      1533
# 3116             D  POINT (-74.21031591361488 40.533181277394675)      1868
# 3117             D  POINT (-74.09878669564895 40.613386552308874)      1762
# 3118             A  POINT (-74.16297563648502 40.616399379236725)      1427
# 3119             D  POINT (-74.07461258089018 40.637163189742914)      1968
#
#                      Position Painted GISPROPNUM  \
# 0                 Out in Open      no       B100
# 1     In Shade, In Playground    None       B302
# 2                 Out in Open     yes       B016
# 3               In Playground      no       B052
# 4                    In Shade    None      B255G
# ...                       ...     ...        ...
# 3115            In Playground     yes       R061
# 3116           Near Ballfield     yes       R106
# 3117              Out in Open      no       R069
# 3118           Near Ballfield     yes      R075A
# 3119              Out in Open      no       R043
#
#                                 SIGNNAME  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square           2  100038957.0
# 1                        Charlie's Place           1  100040304.0
# 2                   Maria Hernandez Park           1  100037411.0
# 3                      Leif Ericson Park           1  100039289.0
# 4                      Butterfly Gardens           1  100040265.0
# ...                                  ...         ...          ...
# 3115                Stapleton Playground           1  100038927.0
# 3116                   Bloomingdale Park           1  100039195.0
# 3117                  Terrace Playground           1  100039136.0
# 3118                  Father Macris Park           1  100038865.0
# 3119                          Lyons Pool           1  100039317.0
#
#             SYSTEM DEPARTMENT PARENTID                   DESCRIPTIO  \
# 0      B100-DF0647       B-11     B100      F High Low, Out in Open
# 1      B302-DF0897       B-03     B302   C, In Shade, In Playground
# 2      B016-DF0013       B-04     B016    E Wheelchair, Out in Open
# 3      B052-DF0762       B-10     B052             C, In Playground
# 4     B255G-DF0895       B-07    B255G                  C, In Shade
# ...            ...        ...      ...                          ...
# 3115   R061-DF0068       R-01     R061  E Wheelchair, In Playground
# 3116   R106-DF0138       R-03     R106            D, Near Ballfield
# 3117   R069-DF0110       R-01     R069               D, Out in Open
# 3118  R075A-DF0021       R-02    R075A            A, Near Ballfield
# 3119   R043-DF0171       R-01     R043               D, Out in Open
#
#      FEATURESTA Data_Collection  Mes        BOROUGH
# 0        Active      2018-02-10    2       Brooklyn
# 1        Active      2018-05-29    5       Brooklyn
# 2        Active      2018-01-11    1       Brooklyn
# 3        Active      2018-02-15    2       Brooklyn
# 4        Active      2018-05-29    5       Brooklyn
# ...         ...             ...  ...            ...
# 3115     Active      2018-02-08    2  Staten Island
# 3116     Active      2018-02-15    2  Staten Island
# 3117     Active      2018-02-13    2  Staten Island
# 3118     Active      2018-02-05    2  Staten Island
# 3119     Active      2018-02-17    2  Staten Island
#
# [3120 rows x 17 columns]
