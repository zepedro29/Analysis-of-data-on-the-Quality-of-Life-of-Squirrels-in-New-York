# %%
# Install dependencies

import sys
# !{sys.executable} -m pip install hdfs
# Out:
# Requirement already satisfied: hdfs in /opt/conda/lib/python3.10/site-packages (2.7.0)
# Requirement already satisfied: docopt in /opt/conda/lib/python3.10/site-packages (from hdfs) (0.6.2)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from hdfs) (1.16.0)
# Requirement already satisfied: requests>=2.7.0 in /opt/conda/lib/python3.10/site-packages (from hdfs) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.7.0->hdfs) (2022.9.24)

# %%
pip install delta-spark
# Out:
# Requirement already satisfied: delta-spark in /opt/conda/lib/python3.10/site-packages (2.1.0)
# Requirement already satisfied: importlib-metadata>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from delta-spark) (4.11.4)
# Requirement already satisfied: pyspark<3.4.0,>=3.3.0 in /usr/local/spark-3.3.0-bin-hadoop3/python (from delta-spark) (3.3.0)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.10/site-packages (from importlib-metadata>=1.0.0->delta-spark) (3.8.1)
# Requirement already satisfied: py4j==0.10.9.5 in /opt/conda/lib/python3.10/site-packages (from pyspark<3.4.0,>=3.3.0->delta-spark) (0.10.9.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from delta import *

# warehouse_location points to the default location for managed databases and tables
warehouse_location = 'hdfs://hdfs-nn:9000/trabalho/gold'

builder = SparkSession \
    .builder \
    .appName("Python Spark SQL Hive integration example") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .config("hive.metastore.uris", "thrift://hive-metastore:9083") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog") \
    .config("spark.jars.packages", "io.delta:delta-core_2.12:1.0.0") \
    .enableHiveSupport() \

spark = spark = configure_spark_with_delta_pip(builder).getOrCreate()

# %%
from pyspark.sql.functions import substring, avg, sum

# read DrinkingFountains from the silver tables
hdfs_path = "hdfs://hdfs-nn:9000/trabalho/silver/Projeto.db/DrinkingFountains"

DrinkingFountains = spark\
             .read\
             .load(hdfs_path)

DrinkingFountains.toPandas()
# Out:
#         FountainTy                                       the_geom  OBJECTID  \
# 0       F High Low   POINT (-73.98659181365889 40.60753207315604)      1589
# 1                C   POINT (-73.94639259466328 40.69933443616386)      2917
# 2     E Wheelchair  POINT (-73.92412001948213 40.703148631662614)        23
# 3                C  POINT (-74.01152114448477 40.630582530228764)      1898
# 4                C  POINT (-73.98647089425904 40.660201255822955)      2894
# ...            ...                                            ...       ...
# 3115  E Wheelchair    POINT (-74.0792508385633 40.62266148329357)      1533
# 3116             D  POINT (-74.21031591361488 40.533181277394675)      1868
# 3117             D  POINT (-74.09878669564895 40.613386552308874)      1762
# 3118             A  POINT (-74.16297563648502 40.616399379236725)      1427
# 3119             D  POINT (-74.07461258089018 40.637163189742914)      1968
#
#                      Position Painted GISPROPNUM  \
# 0                 Out in Open      no       B100
# 1     In Shade, In Playground    None       B302
# 2                 Out in Open     yes       B016
# 3               In Playground      no       B052
# 4                    In Shade    None      B255G
# ...                       ...     ...        ...
# 3115            In Playground     yes       R061
# 3116           Near Ballfield     yes       R106
# 3117              Out in Open      no       R069
# 3118           Near Ballfield     yes      R075A
# 3119              Out in Open      no       R043
#
#                                 SIGNNAME  FountainCo     GISOBJID  \
# 0     Seth Low Playground/ Bealin Square           2  100038957.0
# 1                        Charlie's Place           1  100040304.0
# 2                   Maria Hernandez Park           1  100037411.0
# 3                      Leif Ericson Park           1  100039289.0
# 4                      Butterfly Gardens           1  100040265.0
# ...                                  ...         ...          ...
# 3115                Stapleton Playground           1  100038927.0
# 3116                   Bloomingdale Park           1  100039195.0
# 3117                  Terrace Playground           1  100039136.0
# 3118                  Father Macris Park           1  100038865.0
# 3119                          Lyons Pool           1  100039317.0
#
#             SYSTEM DEPARTMENT PARENTID                   DESCRIPTIO  \
# 0      B100-DF0647       B-11     B100      F High Low, Out in Open
# 1      B302-DF0897       B-03     B302   C, In Shade, In Playground
# 2      B016-DF0013       B-04     B016    E Wheelchair, Out in Open
# 3      B052-DF0762       B-10     B052             C, In Playground
# 4     B255G-DF0895       B-07    B255G                  C, In Shade
# ...            ...        ...      ...                          ...
# 3115   R061-DF0068       R-01     R061  E Wheelchair, In Playground
# 3116   R106-DF0138       R-03     R106            D, Near Ballfield
# 3117   R069-DF0110       R-01     R069               D, Out in Open
# 3118  R075A-DF0021       R-02    R075A            A, Near Ballfield
# 3119   R043-DF0171       R-01     R043               D, Out in Open
#
#      FEATURESTA Data_Collection   Ano        BOROUGH
# 0        Active      2018-02-10  2018       Brooklyn
# 1        Active      2018-05-29  2018       Brooklyn
# 2        Active      2018-01-11  2018       Brooklyn
# 3        Active      2018-02-15  2018       Brooklyn
# 4        Active      2018-05-29  2018       Brooklyn
# ...         ...             ...   ...            ...
# 3115     Active      2018-02-08  2018  Staten Island
# 3116     Active      2018-02-15  2018  Staten Island
# 3117     Active      2018-02-13  2018  Staten Island
# 3118     Active      2018-02-05  2018  Staten Island
# 3119     Active      2018-02-17  2018  Staten Island
#
# [3120 rows x 17 columns]

# %%
from pyspark.sql.functions import count
gold_DrinkingFountains = DrinkingFountains \
    .groupBy("FountainTy", "FEATURESTA")\
    .agg(
        count(DrinkingFountains.FountainTy).alias("Contagem")
    ) \
   
gold_DrinkingFountains.toPandas()
# Out:
#                 FountainTy FEATURESTA  Contagem
# 0                    F Dog     Active        10
# 1                        B     Active       125
# 2                   Trough     Active        57
# 3                 Pedestal     Active        28
# 4               F High Low     Active        36
# 5                        A     Active       986
# 6   Bottle Filler Fountain     Active        16
# 7              CS Concrete     Active        60
# 8             E Wheelchair     Active       374
# 9                        E     Active         7
# 10           Bottle Filler     Active         9
# 11  Bottle Filler High Low     Active        37
# 12      E Wheelchair Child     Active        71
# 13              E High Low     Active        24
# 14                       D     Active       392
# 15                   Other     Active       146
# 16        E Wheelchair Dog     Active        63
# 17                       F     Active        20
# 18                CS Metal     Active        43
# 19                       C     Active       609
# 20         Trough High Low     Active         5
# 21          F High Low Dog     Active         2

# %%
# create DrinkingFountains table in gold
spark.sql(
    """
    DROP TABLE IF EXISTS Projeto_gold.DrinkingFountains2
    """
)

spark.sql(
    """
    CREATE EXTERNAL TABLE Projeto_gold.DrinkingFountains2 (
        FountainTy VARCHAR(250),
        FEATURESTA VARCHAR(500), 
        Contagem LONG
    )
    USING DELTA
    LOCATION 'hdfs://hdfs-nn:9000/trabalho/gold/Projeto_gold.db/DrinkingFountains2/'
    """
)
# Out:
# DataFrame[]

# %%
# write to delta table
gold_DrinkingFountains \
    .write  \
    .format("delta") \
    .mode("overwrite") \
    .save("hdfs://hdfs-nn:9000/trabalho/gold/Projeto_gold.db/DrinkingFountains2/")

# %%
# check the results in the table
spark.table("Projeto_gold.DrinkingFountains2").toPandas()
# Out:
#                 FountainTy FEATURESTA  Contagem
# 0                    F Dog     Active        10
# 1                        B     Active       125
# 2                   Trough     Active        57
# 3                 Pedestal     Active        28
# 4               F High Low     Active        36
# 5                        A     Active       986
# 6   Bottle Filler Fountain     Active        16
# 7              CS Concrete     Active        60
# 8             E Wheelchair     Active       374
# 9                        E     Active         7
# 10           Bottle Filler     Active         9
# 11  Bottle Filler High Low     Active        37
# 12      E Wheelchair Child     Active        71
# 13              E High Low     Active        24
# 14                       D     Active       392
# 15                   Other     Active       146
# 16        E Wheelchair Dog     Active        63
# 17                       F     Active        20
# 18                CS Metal     Active        43
# 19                       C     Active       609
# 20         Trough High Low     Active         5
# 21          F High Low Dog     Active         2

# %%
spark.sql("""
GENERATE symlink_format_manifest FOR TABLE delta.`hdfs://hdfs-nn:9000/trabalho/gold/Projeto_gold.db/DrinkingFountains2/`
""").show()
# Out:
# ++
# ||
# ++
# ++

# %%
spark.sql("""
DROP TABLE IF EXISTS Projeto_gold.DrinkingFountains_Presto2 
""").show()

spark.sql("""
    CREATE EXTERNAL TABLE Projeto_gold.DrinkingFountains_Presto2 (
        FountainTy VARCHAR(250),
        FEATURESTA VARCHAR(500), 
        Contagem LONG
        )
ROW FORMAT SERDE 'org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe'
STORED AS INPUTFORMAT 'org.apache.hadoop.hive.ql.io.SymlinkTextInputFormat'
OUTPUTFORMAT 'org.apache.hadoop.hive.ql.io.HiveIgnoreKeyTextOutputFormat'
LOCATION 'hdfs://hdfs-nn:9000/trabalho/gold/Projeto_gold.db/DrinkingFountains2/_symlink_format_manifest/'
""").show()
# Out:
# ++
# ||
# ++
# ++
#
# ++
# ||
# ++
# ++
